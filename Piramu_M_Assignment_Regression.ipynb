# %% [markdown]
# <a href="https://colab.research.google.com/github/Piramu-Mahalingam/DS-Course-Assignment-1/blob/main/Piramu_M_Assignment_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Piramu M Assignment Regression**

# %% [markdown]
# **A.	Explain the main assumptions of Linear Regression in detail.**

# %% [markdown]
# The 5 assumptions of Linear Regression are as follows:
#
# 1.Linearity:
# The relationship between the dependent variable and the independent variables should be linear. This means that the effect of the predictors on the outcome is constant. A linear regression model assumes this form:
# y=𝛽0+β1x+ϵ
# If the relationship is not linear, the model’s predictions may be inaccurate.
#
# 2.Independence of Errors:
# The residuals (errors) should be independent of each other. This means that the value of the error term for one observation should not depend on another. If errors are correlated (common in time series data), it can lead to biased estimates and incorrect statistical tests.
#
# 3.Homoscedasticity:
# The variance of the errors should be constant across all levels of the independent variables. When the variance changes (heteroscedasticity), the standard errors of coefficients become unreliable, affecting confidence intervals and hypothesis testing.
#
# 4.No Multicollinearity:
# Independent variables should not be highly correlated with each other. High multicollinearity makes it difficult to isolate the individual effect of each variable, leading to unstable and misleading coefficient estimates.
#
# 5.Normality of Residuals:
# The residuals should follow a normal distribution. This assumption is especially important when performing statistical tests (e.g., t-tests for coefficients), as many of these tests rely on normality for valid results.

# %% [markdown]
# **B.	What is the difference between R-squared and Adjusted R-squared?**

# %% [markdown]
# R-squared (R²):
#   a.  R-squared measures the proportion of variance in the dependent
#       variable that is explained by the independent variables.
#   b.  Its value lies between 0 and 1, where a higher R² indicates a better fit.
#   c.  R-squared always increases when more independent variables are added,
#       even if those variables are not statistically significant.
#   d.  This can lead to overfitting.
#           R²=1-(SSres/SStot)
#           Where:SSres= Sum of squares of residuals
#           SStot = Total sum of squares
# 2. Adjusted R-squared (R²_adj):
#   a.  Adjusted R-squared is a modified version of R-squared that adjusts for
#       the number of predictors in the model.
#   b.  It increases only if the new predictor improves the model more than
#       would be expected by chance.
#   c.  It can decrease if unnecessary predictors are added.R²adj=1-(((1-R²)(n-1))/n-k-1)Where:n = number of observations                  k = number of predictors

# %% [markdown]
# **C.	What are the different types of Regularization techniques in Regression. Explain in detail with cost functions of each technique.**

# %% [markdown]
# 1. Ridge Regression (L2 Regularization)
# Adds the square of the coefficients as a penalty.
# Shrinks coefficients but does not eliminate them.
# Cost Function:J(θ)=∑(yi-y'i)2 +λ∑θj2
#
# 2.Lasso Regression (L1 Regularization)
# Adds the absolute value of the coefficients as a penalty.
# Can reduce some coefficients to zero, performing feature selection.
# Cost Function:
# J(θ)=∑(yi-y^)2+λ∑|θj|
#
# 3.Elastic Net Regression
# Combines both L1 and L2 penalties.
# Useful when predictors are correlated or in high-dimensional data.
# Cost Function:
# J(θ)=∑(yi-y^i)2+λ1∑|θj|+λ2∑θj

# %% [markdown]
# **D.	How logistic regression works for multiclass classification. Explain in detail.**

# %% [markdown]
# Logistic Regression is primarily used for binary classification, but it can be extended to handle multiclass classification problems using techniques like One-vs-Rest (OvR) and Multinomial Logistic Regression.
# Multinomial Logistic Regression (Softmax)
#
# building a machine learning model to predict the type of fruit based on features like color, weight, and texture. The possible classes are:
#
# Apple
# Banana
# Orange
#
# This is a multiclass classification problem because there are more than two possible outcomes.
#
# 1. One-vs-Rest (OvR)
# In this method, logistic regression treats each class separately. It builds one model per class:
#
# Model 1: Apple vs. (Banana + Orange)
# Model 2: Banana vs. (Apple + Orange)
# Model 3: Orange vs. (Apple + Banana)
#
# Each model will output the probability of the fruit being a specific class. For example:
#
# Model 1 predicts 0.7 (70% chance it's an Apple)
# Model 2 predicts 0.2 (20% chance it's a Banana)
# Model 3 predicts 0.1 (10% chance it's an Orange)
#
# The class with the highest probability (Apple) is chosen as the final prediction.
#
# 2: Multinomial Logistic Regression (Softmax)
# Instead of training multiple models, this approach uses a single model that considers all three classes at once.
#
# For a new fruit, the model directly predicts the probability of being:
#
# Apple: 70%
# Banana: 20%
# Orange: 10%
#
# Again, the class with the highest probability (Apple) is selected as the output.

# %% [markdown]
# **E.	Explain the performance metrics of logistic regression.**

# %% [markdown]
# Logistic regression is a classification algorithm, so its performance is evaluated using classification metrics. The most common metrics include:
#
# Accuracy
# Measures the proportion of correct predictions (both true positives and true negatives) out of all predictions.
# Best used when the dataset is balanced (i.e., equal number of positive and negative cases).
#
# 2. Precision
# Precision is the proportion of correct positive predictions out of all predicted positives.
# High precision means fewer false positives.
# Useful when false positives are costly (e.g., predicting someone has a disease when they don’t).
#
# 3. Recall (Sensitivity or True Positive Rate)
# Recall is the proportion of actual positives correctly identified.
# High recall means fewer false negatives.
# Important when missing a positive case is critical (e.g., fraud detection or cancer diagnosis).
#
# 4. F1-Score
# The harmonic mean of precision and recall.
# Useful when you need a balance between precision and recall, especially in imbalanced datasets.
#
# 5. ROC-AUC Score (Receiver Operating Characteristic – Area Under Curve)
# Measures how well the model separates positive and negative classes across different thresholds.
# AUC = 1 is perfect; AUC = 0.5 means no better than random guessing.
# Useful for comparing models and handling imbalanced classes.
#
# 6. Confusion Matrix
# A table showing True Positives (TP), True Negatives (TN), False Positives (FP), and False Negatives (FN).
# Helps visualize how well the model is performing across classes.

# %% [markdown]
# **F.	Use the Mobile price prediction dataset from below Kaggle link and create an end to end project on Jupyter/Colab.**

# %% [markdown]
# **	upload the cell phone dataset and display head  and description**

# %%
import pandas as pd
# Load the uploaded Excel file
file_path = "/content/Cellphone.xlsx"
df1= pd.read_excel(file_path)
# Display basic info and first few rows
df1.info(), df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB
# (None,
#     Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# ...

# %% [markdown]
# **ii.	Perform the EDA and do the visualizations.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check for missing values and basic statistics
missing_values = df1.isnull().sum()
stats = df1.describe()

# Correlation heatmap (excluding Product_id)
plt.figure(figsize=(8, 4))
sns.heatmap(df1.drop(columns=['Product_id']).corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Heatmap')
plt.tight_layout()
plt.show()

missing_values, stats
# Out:
# (Product_id      0
#  Price           0
#  Sale            0
#  weight          0
#  resoloution     0
#  ppi             0
#  cpu core        0
#  cpu freq        0
#  internal mem    0
#  ram             0
#  RearCam         0
#  Front_Cam       0
#  battery         0
#  thickness       0
#  dtype: int64,
#          Product_id        Price         Sale      weight  resoloution  \
#  count   161.000000   161.000000   161.000000  161.000000   161.000000
#  mean    675.559006  2215.596273   621.465839  170.426087     5.209938
#  std     410.851583   768.187171  1546.618517   92.888612     1.509953
#  min      10.000000   614.000000    10.000000   66.000000     1.400000
#  25%     237.000000  1734.000000    37.000000  134.100000     4.800000
#  50%     774.000000  2258.000000   106.000000  153.000000     5.150000
#  75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
#  max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
# ...

# %% [markdown]
# **iii.	Check the distributions/skewness in the variables and do the transformations if required.**

# %%
from scipy.stats import skew

# Exclude 'Product_id' and 'Price' from skewness checks
features = df1.drop(columns=['Product_id', 'Price']).columns
skewness = df1[features].apply(skew).sort_values(ascending=False)

# Plot distributions of highly skewed features (|skew| > 1)
high_skew = skewness[abs(skewness) > 1]
plt.figure(figsize=(8, 4))
for i, col in enumerate(high_skew.index):
    plt.subplot(3, 3, i+1)
    sns.histplot(df1[col], kde=True, bins=30)
    plt.title(f'{col} (Skew: {skewness[col]:.2f})')
plt.tight_layout()
plt.show()

skewness
# Out:
# Sale            4.229504
# weight          3.944563
# internal mem    2.367361
# battery         2.073112
# thickness       1.572849
# resoloution     1.165124
# Front_Cam       1.158823
# ram             0.785293
# ppi             0.596875
# RearCam         0.105930
# cpu core       -0.008992
# cpu freq       -0.507874
# dtype: float64

# %% [markdown]
# **iv.	Check/Treat the outliers and do the feature scaling if required.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df1['ram'], kde=True)
# Out:
# <Axes: xlabel='ram', ylabel='Count'>

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score # Changed metrics for regression
from sklearn.preprocessing import StandardScaler # Import StandardScaler
import pandas as pd # Import pandas if not already imported

# Assuming df1 is already loaded from the previous cells

# Separate features (X) and target (y)
X = df1.drop(columns=['Product_id', 'Price']) # Features, excluding Product_id and Price
y = df1['Price'] # Target variable is Price

# Perform feature scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
df_scaled = pd.DataFrame(X_scaled, columns=X.columns) # Convert scaled data back to DataFrame

# Split the scaled data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df_scaled, y, test_size=0.2, random_state=42)

models = {
    'Linear': LinearRegression(),
    'Ridge': Ridge(alpha=1),
    'Lasso': Lasso(alpha=0.01),
    'ElasticNet': ElasticNet(alpha=0.01, l1_ratio=0.5)
}

# Evaluate regression models (using appropriate metrics like MSE and R2)
for name, model in models.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)

    # Calculate regression metrics
    mse = mean_squared_error(y_test, preds)
    r2 = r2_score(y_test, preds)

    print(f"{name} Mean Squared Error: {mse:.2f}")
    print(f"{name} R-squared: {r2:.2f}")
    print("-" * 30)

# Removed the extra 'W' at the end
# Out:
# Linear Mean Squared Error: 21880.49
# Linear R-squared: 0.96
# ------------------------------
# Ridge Mean Squared Error: 22184.48
# Ridge R-squared: 0.96
# ------------------------------
# Lasso Mean Squared Error: 21885.83
# Lasso R-squared: 0.96
# ------------------------------
# ElasticNet Mean Squared Error: 22076.96
# ElasticNet R-squared: 0.96
# ------------------------------
